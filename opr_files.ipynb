# %%
from opr_structs import *
from opr_logic import *
from pprint import pprint

# %%
def build_dwarven_army(playername):
    units = []
    
    # equipment
    hand_weapon = Weapon(1)
    rifle = Weapon(1, {"Range": 18, "AP": 1})
    champion_hand_weapon = Weapon(3, {"AP": 1})
    
    # Dwarf Champion
    units.append(Unit(
        [Model(3, 4, [champion_hand_weapon], rules={"Fearless":0, "Hero":0, "Slow":0, "Tough":3, "Fear":3})], 1, name="Hero"))
    
    dwarf_warrior = Model(4, 5, [hand_weapon], rules={"Shield Wall":0, "Slow":0})
    units.append(Unit(models_for(dwarf_warrior, 10), 5, name="Warriors"))
    
    heavy_hand_weapon = Weapon(1, {"AP": 1})
    veteran = Model(3, 4, [heavy_hand_weapon], rules={"Fearless":0, "Slow":0})
    units.append(Unit(models_for(veteran, 10), 5, name="Veterans"))
    
    great_weapon = Weapon(2, {"AP": 2})
    hammerer = Model(3, 4, [great_weapon], rules={"Slow":0})
    units.append(Unit(models_for(hammerer, 5), 5, name="Hammerers"))
    
    rifle_dwarf = Model(4, 5, [rifle, hand_weapon], rules={"Slow":0})
    units.append(Unit(models_for(rifle_dwarf, 5), 5, name="Marksmen"))
    
    fire_rifle = Weapon(2, {"Range": 18, "Rending": 0})
    drake_marksman = Model(3, 3, [fire_rifle, hand_weapon], rules={"Slow":0})
    units.append(Unit(models_for(drake_marksman, 5), 5, name="Drakes"))
    
    crew = Weapon(3)
    bolt_thrower = Weapon(1, {"Range": 36, "AP": 3, "Deadly":6})
    units.append(Unit([Model(4, 5, [crew, bolt_thrower], rules={"Immobile":0, "Entrenched":0, "Tough":3})], 1, name="Arty"))
    
    return units
build_dwarven_army("dwarves")
# Out:
# [Unit(Hero (1/1)(0.0,0.0),
#  Unit(Warriors (10/10)(0.0,0.0),
#  Unit(Veterans (10/10)(0.0,0.0),
#  Unit(Hammerers (5/5)(0.0,0.0),
#  Unit(Marksmen (5/5)(0.0,0.0),
#  Unit(Drakes (5/5)(0.0,0.0),
#  Unit(Arty (1/1)(0.0,0.0)]

# %%
def build_elven_army(playername):
    units = []
    
    # equipment
    hand_weapon = Weapon(1)
    champion_hand_weapon = Weapon(3, {"AP": 1})
    
    # Champion
    units.append(Unit(
        [Model(3, 4, [champion_hand_weapon], rules={"Hero":0, "Tough":3})], 1, name="Noble"))
    
    warrior = Model(4, 5, [hand_weapon])
    units.append(Unit(models_for(warrior, 10), 5, name="Elf Warriors"))
    
    heavy_halberds = Weapon(1, {"AP": 1, "Rending": 0})
    phoenix = Model(3, 4, [heavy_halberds], rules={"Regeneration":0})
    units.append(Unit(models_for(phoenix, 5), 5, name="Pheonix"))
    
    longbow = Weapon(1, {"Range": 30})
    archer = Model(4, 5, [hand_weapon, longbow])
    units.append(Unit(models_for(archer, 5), 5, name="Archers"))
    
    # Silver Cavalry
    lance = Weapon(1, {"Lance": 0})
    cavalry = Model(4, 4, [lance], rules={"Fast":0, "Impact":1})
    units.append(Unit(models_for(cavalry, 5), 5, name="Cavalry"))
    
    # Giant Eagles
    claws = Weapon(2)
    eagle = Model(4, 4, [claws], rules={"Fast":0, "Flying":0, "Impact":2, "Tough":3})
    units.append(Unit(models_for(eagle, 3), 3, name="Eagles"))
    
    axe_crew = Weapon(4)
    heavy_claw = Weapon(2, {"AP": 1})
    chariot = Model(4, 4, [heavy_claw, axe_crew], rules={"Fast":0, "Fear":1, "Fearless":0, "Impact":2, "Stealth":0, "Tough":6})
    units.append(Unit([chariot], 1, name="Chariot"))
    
    return units
build_elven_army("elves")
# Out:
# [Unit(Noble (1/1)(0.0,0.0),
#  Unit(Elf Warriors (10/10)(0.0,0.0),
#  Unit(Pheonix (5/5)(0.0,0.0),
#  Unit(Archers (5/5)(0.0,0.0),
#  Unit(Cavalry (5/5)(0.0,0.0),
#  Unit(Eagles (3/3)(0.0,0.0),
#  Unit(Chariot (1/1)(0.0,0.0)]

# %%
def build_knightly_army(playername):
    units = []
    
    # equipment
    hand_weapon = Weapon(1)
    champion_hand_weapon = Weapon(3, {"AP": 1})
    
    # Champion
    units.append(Unit(
        [Model(4, 4, [champion_hand_weapon], rules={"Hero":0, "Tough":3, "Fearless":0})], 1, name="HighC"))
    
    rocks = Weapon(1, {"Range": 12})
    peasant = Model(6, 6, [hand_weapon, rocks])
    units.append(Unit(models_for(peasant, 20), 5, name="Peasants"))
    
    man_at_arms = Model(5, 5, [hand_weapon])
    units.append(Unit(models_for(man_at_arms, 20), 5, name="Medium"))
    
    heavy_hand_weapon = Weapon(1, {"AP": 1})
    foot_knight = Model(4, 4, [heavy_hand_weapon], rules={"Fearless":0})
    units.append(Unit(models_for(foot_knight, 5), 5, name="Heavy"))
    
    longbow = Weapon(1, {"Range": 30})
    archer = Model(5, 5, [hand_weapon, longbow])
    units.append(Unit(models_for(archer, 5), 5, name="Archers"))
    
    lance = Weapon(1, {"Lance": 0})
    cavalry = Model(4, 4, [lance], rules={"Fast":0, "Fearless":0, "Furious":0, "Impact":1, "Joust":0})
    units.append(Unit(models_for(cavalry, 10), 5, name="Knights"))

    crew = Weapon(3)
    stone_thrower = Weapon(1, {"Range": 36, "AP": 2, "Blast":6, "Indirect":0})
    units.append(Unit([Model(5, 5, [crew, stone_thrower], rules={"Immobile":0, "Entrenched":0, "Tough":3})], 1, name="StoneArty"))
    
    return units
build_knightly_army("knights")
# Out:
# [Unit(HighC (1/1)(0.0,0.0),
#  Unit(Peasants (20/20)(0.0,0.0),
#  Unit(Medium (20/20)(0.0,0.0),
#  Unit(Heavy (5/5)(0.0,0.0),
#  Unit(Archers (5/5)(0.0,0.0),
#  Unit(Knights (10/10)(0.0,0.0),
#  Unit(StoneArty (1/1)(0.0,0.0)]

# %%
import matplotlib.pyplot as plt
def plot_battle(battle):
    y = []
    x = []
    names = []
    for u in battle.all_units:
        x.append(u.x)
        y.append(u.y)
        names.append(repr(u))
    
    fig, ax = plt.subplots()
    ax.scatter(x, y)
    ax.set_xlim([0, 72])
    ax.set_ylim([0, 48])
    
    for i, n in enumerate(names):
        ax.annotate(n, (x[i], y[i]))
    plt.show()

# %%
p1 = Player("p1", build_dwarven_army("p1"), (0, 12, 0, 72))
p2 = Player("p2", build_elven_army("p2"), (36, 48, 0, 72))
battle = Battle([p1, p2])
deploy(battle)
plot_battle(battle)

# %%
next_player = 0
for i in range(4):
    print()
    next_player = do_round(battle, next_player)
    plot_battle(battle)
    print("Units:")
    pprint(battle.all_units)
    pprint(battle.objectives)
# Out:
# Starting Round 1
# Unit(Arty (1/1)(55.0,1.0) ('Advance', 0, -3.0072712116368248, Unit(Chariot (1/1)(60.0,38.0))
# Unit(Arty (1/1)(55.0,1.0) shooting at Unit(Chariot (1/1)(60.0,38.0)
# Out of range
# Unit(Pheonix (5/5)(23.0,48.0) ('Rush', 12, 0.4297622790966885)
# Unit(Drakes (5/5)(15.0,4.0) ('Advance', 4, -3.0511770253331063, Unit(Pheonix (5/5)(18.0,37.1))
# Unit(Drakes (5/5)(15.4,8.0) shooting at Unit(Pheonix (5/5)(18.0,37.1)
# Out of range
# Unit(Noble (1/1)(36.0,41.0) ('Rush', 12, 0.0)
# Unit(Hammerers (5/5)(58.0,7.0) ('Rush', 8, -3.024483909022929)
# Unit(Archers (5/5)(35.0,36.0) ('Advance', 6, -0.31099828060554097, Unit(Hero (1/1)(44.0,8.0))
# Unit(Archers (5/5)(36.8,30.3) shooting at Unit(Hero (1/1)(44.0,8.0)
# 5 attacks
# 1 hits
# 1 wounds
# Unit(Marksmen (5/5)(24.0,8.0) ('Advance', 4, -2.62244653934327, Unit(Noble (1/1)(36.0,29.0))
# Unit(Marksmen (5/5)(26.0,11.5) shooting at Unit(Noble (1/1)(36.0,29.0)
# Out of range
# Unit(Elf Warriors (10/10)(4.0,42.0) ('Rush', 12, -0.4182243295792291)
# Unit(Warriors (10/10)(19.0,0.0) ('Rush', 8, 2.8577985443814655)
# Unit(Eagles (3/3)(13.0,42.0) ('Rush', 16, 0.05549850524571683)
# Unit(Hero (1/1)(44.0,8.0) ('Rush', 8, 2.677945044588987)
# Unit(Chariot (1/1)(60.0,38.0) ('Rush', 16, 0.0)
# Unit(Veterans (10/10)(43.0,3.0) ('Rush', 8, 2.819842099193151)
# Unit(Cavalry (5/5)(17.0,47.0) ('Rush', 16, 0.21406068356382152)
# Units:
# [Unit(Hero (1/1)(40.4,15.2),
#  Unit(Warriors (10/10)(16.8,7.7),
#  Unit(Veterans (10/10)(40.5,10.6),
#  Unit(Hammerers (5/5)(58.9,14.9),
#  Unit(Marksmen (5/5)(26.0,11.5),
#  Unit(Drakes (5/5)(15.4,8.0),
#  Unit(Arty (1/1)(55.0,1.0),
#  Unit(Noble (1/1)(36.0,29.0),
#  Unit(Elf Warriors (10/10)(8.9,31.0),
#  Unit(Pheonix (5/5)(18.0,37.1),
#  Unit(Archers (5/5)(36.8,30.3),
#  Unit(Cavalry (5/5)(13.6,31.4),
#  Unit(Eagles (3/3)(12.1,26.0),
#  Unit(Chariot (1/1)(60.0,22.0)]
# [Objective(12, 24, p2), Objective(36, 24, None), Objective(60, 24, p2)]
#
# Starting Round 2
# Unit(Marksmen (5/5)(26.0,11.5) ('Advance', 4, 2.3800990261486663, Unit(Eagles (3/3)(12.1,26.0))
# Unit(Marksmen (5/5)(23.2,14.4) shooting at Unit(Eagles (3/3)(12.1,26.0)
# 5 attacks
# 3 hits
# 3 wounds
# Unit(Elf Warriors (10/10)(8.9,31.0) ('Rush', 12, -1.317070174946977)
# Unit(Veterans (10/10)(40.5,10.6) ('Rush', 8, 2.819842099193151)
# Unit(Noble (1/1)(36.0,29.0) ('Rush', 8.0, 0.0)
# Unit(Drakes (5/5)(15.4,8.0) ('Advance', 4, 2.9634291092553617, Unit(Eagles (2/3)(12.1,26.0))
# Unit(Drakes (5/5)(14.7,11.9) shooting at Unit(Eagles (2/3)(12.1,26.0)
# 10 attacks
# 7 hits
# 5 wounds
# Eagles doing ranged morale test
# Unit(Archers (5/5)(36.8,30.3) ('Advance', 6, -0.09094589459353332, Unit(Veterans (10/10)(37.9,18.2))
# Unit(Archers (5/5)(37.4,24.3) shooting at Unit(Veterans (10/10)(37.9,18.2)
# 5 attacks
# 0 hits
# 0 wounds
# Unit(Arty (1/1)(55.0,1.0) ('Advance', 0, -2.907849472720892, Unit(Chariot (1/1)(60.0,22.0))
# Unit(Arty (1/1)(55.0,1.0) shooting at Unit(Chariot (1/1)(60.0,22.0)
# 1 attacks
# Target is stealthed
# 0 hits
# 0 wounds
# Unit(Eagles (1/3)(12.1,26.0) ('Rush', 16, -1.4862414228841079)
# Unit(Hero (1/1)(40.4,15.2) ('Charge', Unit(Noble (1/1)(36.0,21.0))
# Unit(Hero (1/1)(37.2,19.4) strikes Unit(Noble (1/1)(36.0,21.0)
# 3 attacks
# 2 hits
# 2 wounds
# Unit(Noble (1/1)(36.0,21.0) strikes Unit(Hero (1/1)(37.2,19.4)
# 3 attacks
# 3 hits
# 2 wounds
# Unit(Hero (0/1)(37.2,19.4) has been slain!
# Unit(Chariot (1/1)(60.0,22.0) ('Rush', 16, 1.6539375586833378)
# Unit(Hammerers (5/5)(58.9,14.9) ('Rush', 8, -3.0244839090229285)
# Unit(Cavalry (5/5)(13.6,31.4) ('Rush', 16, -1.253114049982482)
# Unit(Warriors (10/10)(16.8,7.7) ('Rush', 8, 2.8577985443814655)
# Unit(Pheonix (5/5)(18.0,37.1) ('Rush', 12, -0.9419848743968298)
# Units:
# [Unit(Hero (0/1)(37.8,18.6),
#  Unit(Warriors (10/10)(14.5,15.4),
#  Unit(Veterans (10/10)(37.9,18.2),
#  Unit(Hammerers (5/5)(59.9,22.9),
#  Unit(Marksmen (5/5)(23.2,14.4),
#  Unit(Drakes (5/5)(14.7,11.9),
#  Unit(Arty (1/1)(55.0,1.0),
#  Unit(Noble (1/1)(36.0,21.0),
#  Unit(Elf Warriors (10/10)(20.5,28.0),
#  Unit(Pheonix (5/5)(27.7,30.0),
#  Unit(Archers (5/5)(37.4,24.3),
#  Unit(Cavalry (5/5)(28.8,26.4),
#  Unit(Eagles (1/3)(28.1,24.7),
#  Unit(Chariot (1/1)(44.1,23.3)]
# [Objective(12, 24, p2), Objective(36, 24, p2), Objective(60, 24, p1)]
#
# Starting Round 3
# Unit(Marksmen (5/5)(23.2,14.4) ('Advance', 4, -2.703238068714795, Unit(Eagles (1/3)(28.1,24.7))
# Unit(Marksmen (5/5)(24.9,18.0) shooting at Unit(Eagles (1/3)(28.1,24.7)
# 5 attacks
# 0 hits
# 0 wounds
# Unit(Noble (1/1)(36.0,21.0) ('Charge', Unit(Veterans (10/10)(37.9,18.2))
# Unit(Noble (1/1)(36.8,19.8) strikes Unit(Veterans (10/10)(37.9,18.2)
# 3 attacks
# 0 hits
# 0 wounds
# Unit(Veterans (10/10)(37.9,18.2) strikes Unit(Noble (1/1)(36.8,19.8)
# 10 attacks
# 7 hits
# 1 wounds
# Unit(Noble (0/1)(36.8,19.8) has been slain!
# Unit(Veterans (10/10)(37.9,18.2) ('Charge', Unit(Archers (5/5)(37.4,24.3))
# Unit(Veterans (10/10)(37.6,22.3) strikes Unit(Archers (5/5)(37.4,24.3)
# 10 attacks
# 1 hits
# 0 wounds
# Unit(Archers (5/5)(37.4,24.3) strikes Unit(Veterans (10/10)(37.6,22.3)
# 5 attacks
# 0 hits
# 0 wounds
# scores: a: 2, d: 1
# Archers doing morale test
# Archers failed morale test
# Unit(Pheonix (5/5)(27.7,30.0) ('Rush', 12, -1.3861161860313918)
# Unit(Drakes (5/5)(14.7,11.9) ('Advance', 4, -2.7938093487823523, Unit(Elf Warriors (10/10)(20.5,28.0))
# Unit(Drakes (5/5)(16.0,15.7) shooting at Unit(Elf Warriors (10/10)(20.5,28.0)
# 10 attacks
# 2 hits
# 2 wounds
# Unit(Chariot (1/1)(44.1,23.3) ('Charge', Unit(Hammerers (5/5)(59.9,22.9))
# Unit(Chariot (1/1)(57.9,22.9) strikes Unit(Hammerers (5/5)(59.9,22.9)
# 8 attacks
# 4 hits
# 3 wounds
# Unit(Hammerers (2/5)(59.9,22.9) strikes Unit(Chariot (1/1)(57.9,22.9)
# 4 attacks
# 2 hits
# 1 wounds
# scores: a: 4, d: 1
# Hammerers doing morale test
# Unit(Warriors (10/10)(14.5,15.4) ('Rush', 8, 2.857798544381465)
# Unit(Eagles (1/3)(28.1,24.7) ('Charge', Unit(Veterans (10/10)(37.7,21.3))
# Unit(Eagles (1/3)(35.8,22.0) strikes Unit(Veterans (10/10)(37.7,21.3)
# 4 attacks
# 2 hits
# 1 wounds
# Unit(Veterans (9/10)(37.7,21.3) strikes Unit(Eagles (1/3)(35.8,22.0)
# 9 attacks
# 1 hits
# 1 wounds
# Unit(Eagles (0/3)(35.8,22.0) has been slain!
# Unit(Arty (1/1)(55.0,1.0) ('Advance', 0, -3.0566671786652897, Unit(Chariot (1/1)(56.9,23.0))
# Unit(Arty (1/1)(55.0,1.0) shooting at Unit(Chariot (1/1)(56.9,23.0)
# 1 attacks
# Target is stealthed
# 0 hits
# 0 wounds
# Unit(Archers (5/5)(37.4,24.3) ('Hold',)
# Unit(Hammerers (2/5)(59.9,22.9) ('Charge', Unit(Chariot (1/1)(56.9,23.0))
# Unit(Hammerers (2/5)(58.9,22.9) strikes Unit(Chariot (1/1)(56.9,23.0)
# 4 attacks
# 1 hits
# 1 wounds
# Unit(Chariot (1/1)(56.9,23.0) strikes Unit(Hammerers (2/5)(58.9,22.9)
# 6 attacks
# 1 hits
# 1 wounds
# scores: a: 1, d: 2
# Hammerers doing morale test
# Unit(Cavalry (5/5)(28.8,26.4) ('Charge', Unit(Veterans (9/10)(37.7,21.3))
# Unit(Cavalry (5/5)(35.9,22.3) strikes Unit(Veterans (9/10)(37.7,21.3)
# 10 attacks
# 8 hits
# 3 wounds
# Unit(Veterans (6/10)(37.7,21.3) strikes Unit(Cavalry (5/5)(35.9,22.3)
# 6 attacks
# 0 hits
# 0 wounds
# scores: a: 4, d: 1
# Veterans doing morale test
# skipping
# Unit(Elf Warriors (8/10)(20.5,28.0) ('Rush', 12, -1.4693473526463998)
# Units:
# [Unit(Hero (0/1)(37.8,18.6),
#  Unit(Warriors (10/10)(12.3,23.0),
#  Unit(Veterans (6/10)(37.7,21.3),
#  Unit(Hammerers (1/5)(59.9,22.9),
#  Unit(Marksmen (5/5)(24.9,18.0),
#  Unit(Drakes (5/5)(16.0,15.7),
#  Unit(Arty (1/1)(55.0,1.0),
#  Unit(Noble (0/1)(36.2,20.7),
#  Unit(Elf Warriors (8/10)(32.4,26.8),
#  Unit(Pheonix (5/5)(39.5,27.8),
#  Unit(Archers (5/5)(37.4,24.3),
#  Unit(Cavalry (5/5)(35.0,22.8),
#  Unit(Eagles (0/3)(34.8,22.3),
#  Unit(Chariot (1/1)(56.9,23.0)]
# [Objective(12, 24, p1), Objective(36, 24, None), Objective(60, 24, None)]
#
# Starting Round 4
# Unit(Hammerers (1/5)(59.9,22.9) ('Rush', 4.11724276862369, -3.0244839090229294)
# Unit(Pheonix (5/5)(39.5,27.8) ('Charge', Unit(Veterans (6/10)(37.7,21.3))
# Unit(Pheonix (5/5)(38.2,23.2) strikes Unit(Veterans (6/10)(37.7,21.3)
# 5 attacks
# 4 hits
# 3 wounds
# Unit(Veterans (3/10)(37.7,21.3) strikes Unit(Pheonix (5/5)(38.2,23.2)
# 3 attacks
# 0 hits
# 0 wounds
# scores: a: 4, d: 0
# Veterans doing morale test
# Unit(Drakes (5/5)(16.0,15.7) ('Advance', 4, -2.1665394599477468, Unit(Elf Warriors (8/10)(32.4,26.8))
# Unit(Drakes (5/5)(19.3,17.9) shooting at Unit(Elf Warriors (8/10)(32.4,26.8)
# 10 attacks
# 1 hits
# 1 wounds
# Unit(Cavalry (5/5)(35.0,22.8) ('Rush', 4.524982845723612, -2.4662373555876824)
# Unit(Marksmen (5/5)(24.9,18.0) ('Advance', 4, -2.436365568120589, Unit(Elf Warriors (7/10)(32.4,26.8))
# Unit(Marksmen (5/5)(27.5,21.0) shooting at Unit(Elf Warriors (7/10)(32.4,26.8)
# 5 attacks
# 1 hits
# 1 wounds
# Unit(Elf Warriors (6/10)(32.4,26.8) ('Charge', Unit(Veterans (3/10)(37.7,21.3))
# Unit(Elf Warriors (6/10)(36.3,22.8) strikes Unit(Veterans (3/10)(37.7,21.3)
# 6 attacks
# 4 hits
# 2 wounds
# Unit(Veterans (1/10)(37.7,21.3) strikes Unit(Elf Warriors (6/10)(36.3,22.8)
# 1 attacks
# 0 hits
# 0 wounds
# scores: a: 3, d: 0
# Veterans doing morale test
# Unit(Warriors (10/10)(12.3,23.0) ('Rush', 8, -1.611246426099577)
# Unit(Chariot (1/1)(56.9,23.0) ('Charge', Unit(Hammerers (1/5)(60.4,27.0))
# Unit(Chariot (1/1)(59.0,25.5) strikes Unit(Hammerers (1/5)(60.4,27.0)
# 8 attacks
# 3 hits
# 1 wounds
# Unit(Hammerers (0/5)(60.4,27.0) has been slain!
# Unit(Arty (1/1)(55.0,1.0) ('Advance', 0, -2.9998895570816995, Unit(Chariot (1/1)(58.4,24.7))
# Unit(Arty (1/1)(55.0,1.0) shooting at Unit(Chariot (1/1)(58.4,24.7)
# 1 attacks
# Target is stealthed
# 0 hits
# 0 wounds
# Unit(Archers (5/5)(37.4,24.3) ('Advance', 6, -0.09094589459353489, Unit(Veterans (1/10)(37.7,21.3))
# Unit(Archers (5/5)(37.9,18.3) shooting at Unit(Veterans (1/10)(37.7,21.3)
# 5 attacks
# 1 hits
# 0 wounds
# Unit(Veterans (1/10)(37.7,21.3) ('Charge', Unit(Elf Warriors (6/10)(35.6,23.5))
# Unit(Veterans (1/10)(37.0,22.0) strikes Unit(Elf Warriors (6/10)(35.6,23.5)
# 1 attacks
# 0 hits
# 0 wounds
# Unit(Elf Warriors (6/10)(35.6,23.5) strikes Unit(Veterans (1/10)(37.0,22.0)
# 6 attacks
# 0 hits
# 0 wounds
# scores: a: 0, d: 1
# Veterans doing morale test
# Units:
# [Unit(Hero (0/1)(37.8,18.6),
#  Unit(Warriors (10/10)(20.3,23.4),
#  Unit(Veterans (1/10)(37.7,21.3),
#  Unit(Hammerers (0/5)(60.4,27.0),
#  Unit(Marksmen (5/5)(27.5,21.0),
#  Unit(Drakes (5/5)(19.3,17.9),
#  Unit(Arty (1/1)(55.0,1.0),
#  Unit(Noble (0/1)(36.2,20.7),
#  Unit(Elf Warriors (6/10)(35.6,23.5),
#  Unit(Pheonix (5/5)(38.5,24.2),
#  Unit(Archers (5/5)(37.9,18.3),
#  Unit(Cavalry (5/5)(37.9,26.3),
#  Unit(Eagles (0/3)(34.8,22.3),
#  Unit(Chariot (1/1)(58.4,24.7)]
# [Objective(12, 24, p1), Objective(36, 24, None), Objective(60, 24, p2)]

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
w.value
# Out:
# 39

# %%
# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 8]
matplotlib.rcParams['figure.facecolor'] = '1.0'
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

def f(m, b):
    plt.figure(2)
    x = np.linspace(-10, 10, num=1000)
    plt.plot(x, m * x + b)
    plt.ylim(-5, 5)
    plt.show()

interactive_plot = interactive(f, m=(-2.0, 2.0), b=(-3, 3, 0.5))
output = interactive_plot.children[-1]
# output.layout.height = '550px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='m', max=2.0, min=-2.0), FloatSlider(value=0.0, descr…

# %%
import matplotlib.pyplot as plt
import pandas as pd
import ipywidgets as widgets
import numpy as np

out1 = widgets.Output()
out2 = widgets.Output()
data1 = pd.DataFrame(np.random.normal(size = 50))
data2 = pd.DataFrame(np.random.normal(size = 100))

tab = widgets.Tab(children = [out1, out2])
tab.set_title(0, 'First')
tab.set_title(1, 'Second')
display(tab)

with out1:
    fig = plt.figure(figsize=(10,8))
    axes1 = fig.subplots()
    data1.hist(ax = axes1)
#     fig1.figsize = [10, 8]
    plt.show(fig)

with out2:
    fig2, axes2 = plt.subplots()
    data2.hist(ax = axes2)
    plt.show(fig2)
# Out:
# Tab(children=(Output(), Output()), _titles={'0': 'First', '1': 'Second'})

# %%
import matplotlib.pyplot as plt

def plot_items(ax, items, name_func):
    y = []
    x = []
    names = []
    for i in items:
        x.append(i.x)
        y.append(i.y)
        name = name_func(i) #f"{u.name} ({len(u.models)}/{u.starting_models})"
        names.append(name)
    
    ax.scatter(x, y)
    for i, n in enumerate(names):
        ax.annotate(n, (x[i], y[i]))

def plot_battle(battle, cursor_x, cursor_y):
    fig = plt.figure(figsize=(10,8))
    ax = fig.subplots()
    for p in battle.players:
        plot_items(ax, [u for u in p.units if u.alive], lambda u: f"{u.name} ({len(u.models)}/{u.starting_models})")
    
    plot_items(ax, battle.objectives, lambda o: f"{o.controller}")
    
    ax.scatter(cursor_x, cursor_y, c="red")
    ax.set_xlim([0, 72])
    ax.set_ylim([0, 48])
    
    
    plt.gca().set_aspect('equal')
    

    plt.show()

# %%
plot_battle(battle, 20, 30)

# %% [markdown]
# we can edit the dropdowns after creating the ui, and then we only need to display it once.
#
# I need to refactor the game loop to a state machine that just takes actions as inputs

# %%
button = widgets.Button(
    description='Submit',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
#     icon='check' # (FontAwesome names without the `fa-` prefix)
)
button
action = widgets.ToggleButtons(
    options=['Hold', 'Advance', 'Rush', 'Charge'],
    description='Action:',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
#     tooltips=['Description of slow', 'Description of regular', 'Description of fast'],
#     icons=['check'] * 3
)
# display(button)
selection = widgets.Dropdown(options=["a", "b", "c"])
angle = widgets.FloatSlider(max=2*math.pi)
distance = widgets.FloatSlider(max=12)
target = widgets.Dropdown(options=["ta", "tb", "tc"])

vbox = widgets.VBox([button, selection, action, angle, distance, target])

display(vbox)
# Out:
# VBox(children=(Button(description='Submit', style=ButtonStyle(), tooltip='Click me'), Dropdown(options=('a', '…

# %%
vbox.children[1].options = ["1", "2", "3"]
